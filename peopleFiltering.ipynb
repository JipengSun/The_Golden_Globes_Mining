# %%
import json
import string

import nltk
import numpy
from nltk.tag.stanford import StanfordNERTagger

# %%
f = open('./gg2013.json',)
data = json.load(f)
for i in range(0,100):
    print(data[i])
f.close()
# Out:
# {'text': "JLo's dress! #eredcarpet #GoldenGlobes", 'user': {'screen_name': 'Dozaaa_xo', 'id': 557374298}, 'id': 290620657987887104, 'timestamp_ms': 1358124338000}
# {'text': "What's making Sofia Vergara's boobs stay like that? Magic? Witchcraft? #GoldenGlobes", 'user': {'screen_name': 'theAmberShow', 'id': 14648726}, 'id': 290620657887219713, 'timestamp_ms': 1358124338000}
# {'text': 'RT @FabSugar: Kerry Washington is EVERYTHING. Dying over her Miu Miu gown! @goldenglobes #goldenglobes http://t.co/3feH7MvO', 'user': {'screen_name': 'SweetyPW', 'id': 35498686}, 'id': 290620657828524032, 'timestamp_ms': 1358124338000}
# {'text': 'Anne Hathaway has got me living. #GoldenGlobes', 'user': {'screen_name': '_NicoleEdwards', 'id': 144430208}, 'id': 290620657799159809, 'timestamp_ms': 1358124338000}
# {'text': "Jennifer Lopez's lace dress? Thoughts? #GoldenGlobes", 'user': {'screen_name': 'lolaogunnaike', 'id': 134953223}, 'id': 290620657778188288, 'timestamp_ms': 1358124338000}
# ...

# %%
f = open('./gg2013.json',)
data = json.load(f)
st = StanfordNERTagger('stanford-ner/classifiers/english.all.3class.distsim.crf.ser.gz','stanford-ner/stanford-ner.jar')
print(len(data))
punc = string.punctuation
nameData= []

for i in range(0,len(data)):
    #print(data[0]['text'])
    #print(i)
    tokens1 = nltk.word_tokenize((data[i]['text']))
    tokens = []
    for token in tokens1:
        if not(token.islower()) and token not in punc:
            tokens.append(token)
    #print(tokens)
    tags = st.tag(tokens)
    for tag in tags:
        if tag[1] == 'PERSON':
            nameData.append(data[i])
            break
    if i % 10 ==0:
        print(i)
    if i % 100 == 0:
        print(i)
        filename = 'data ' + str(i) + '.txt'
        with open('./Person Data/'+filename, 'w') as f:
            json.dump(nameData, f, ensure_ascii=False)
        f.close()
        nameData = []
# Out:
# 174643
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100

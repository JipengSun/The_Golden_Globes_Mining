# %%
import json 
import pandas as pd
import re
import nltk
import difflib
from nltk.util import ngrams
from collections import Counter

#Strategy 1 scan after the word won:
df = pd.read_json("gg2013.json/gg2013.json")
df2 = df[df['text'].str.contains(" won ") | df['text'].str.contains(" Won ")]
tweets = df2['text'].tolist()
keywords = []
regexp = re.compile(r'[!?.]+(?=$|\s)')

#Parse Keywords
for tweet in tweets:
    words = tweet.lower().split()
    index_won = words.index("won")
    if words[index_won + 1] == "best":
        keyword = "best "
        curr_index = index_won + 2
        while curr_index != len(words):
            if regexp.search(words[curr_index]):
                keyword += words[curr_index]
                break
            keyword += words[curr_index] + " "
            curr_index += 1
        keywords.append(keyword)

#Analyze common phrase occurences
#Longest award phrase is 12 words
def common_phrases(keywords):
    bigrams = []
    trigrams = []
    quadgrams = []
    multigrams = []
    megagrams = []
    for item in keywords:
        clean_string = re.sub('[^A-Za-z0-9]+', ' ', item)
        tokens = nltk.word_tokenize(clean_string)
        grams2 = ngrams(tokens, 2)
        grams3 = ngrams(tokens, 3)
        grams4 = ngrams(tokens, 4)
        grams9 = ngrams(tokens, 9)
        grams12 = ngrams(tokens, 12)
        for gram in grams2:
            bigrams.append(gram)
        for gram in grams3:
            trigrams.append(gram)
        for gram in grams4:
            quadgrams.append(gram)
        for gram in grams9:
            multigrams.append(gram)
        for gram in grams12:
            megagrams.append(gram)

    common2 = Counter(bigrams).most_common()
    common3 = Counter(trigrams).most_common()
    common4 = Counter(quadgrams).most_common()
    common9 = Counter(multigrams).most_common()
    common12 = Counter(megagrams).most_common()

    common2 = filter(lambda x: x[0][0] == "best", common2)
    common3 = filter(lambda x: x[0][0] == "best", common3)
    common4 = filter(lambda x: x[0][0] == "best", common4)
    common9 = filter(lambda x: x[0][0] == "best", common9)
    common12 = filter(lambda x: x[0][0] == "best", common12)

    common2 = list(common2)
    common3 = list(common3)
    common4 = list(common4)
    common9 = list(common9)
    common12 = list(common12)

    combined = common2 + common3 + common4 + common9 + common12
    return combined

strategy1 = common_phrases(keywords)

#Strategy 2 scan before the word won:
df3 = df[df['text'].str.contains(" goes to ")]
tweets = df3['text'].tolist()
keywords2 = []

#Parse Backwards, stop at the word best
for tweet in tweets:
    words = tweet.lower().split()
    index = words.index("to")
    if words[index - 1] == "goes":
        keyword = ""
        curr_index = index - 2
        while curr_index >= 0:
            if curr_index == 0 or words[curr_index] == "best":
                keyword = words[curr_index] + keyword
                break
            keyword = " " + words[curr_index] + keyword
            curr_index -= 1
        keywords2.append(keyword)
        
strategy2 = common_phrases(keywords2)

#Can also count common strings in strings for strategy2
def most_common_beststring(strings):
    best_string = filter(lambda x: "best" in x, strings)
    best_string = list(best_string)
    return Counter(best_string).most_common()

common_strings = most_common_beststring(keywords2)

def accumulate_votes(grams1, grams2, common_strings):
    awards = {}
    for gram in grams1:
        untokenize = ' '.join(gram[0])
        awards[untokenize] = len(gram[0]) * gram[1]
    for gram in grams2:
        untokenize = ' '.join(gram[0])
        if untokenize in awards:
            awards[untokenize] = awards[untokenize] * 2.5
        else:
            awards[untokenize] = len(gram[0]) * gram[1]
    for string in common_strings:
        first_two = ' '.join(string[0].split()[:2])
        if string[0] in awards:
            awards[string[0]] = awards[string[0]] * 2.5
        elif first_two in awards:
            awards[string[0]] = awards[first_two] * string[1]
        else:
            awards[string[0]] = len(string[0]) * string[1] 
    return sorted(awards.items(), key = lambda x: x[1], reverse = True)
votes = accumulate_votes(strategy1, strategy2, common_strings)
#Need a way to combine similar categories
votes
# Out:
# [('best director for motion picture', 9500.0),
#  ('best supporting actor, motion picture', 8880.0),
#  ('best director - motion picture', 7600.0),
#  ('best actress in a mini-series/tv movie', 7150.0),
#  ('best actress in a motion picture drama', 7150.0),
#  ('best actress in a tv comedy or musical', 6380.0),
#  ('best supporting actress tv series, miniseries, or tv movie', 4070.0),
#  ('best actress in a tv series, drama,', 3850.0),
#  ('best actress in a tv comedy/musical', 3300.0),
#  ('best actor in a miniseries/tv movie', 2720.0),
#  ('best actor tv series - comedy or musical', 2240.0),
#  ('best supporting actress in a motion picture', 2220.0),
#  ('best actress for comedy/musical', 2200.0),
#  ('best actress tv series comedy', 2200.0),
#  ('best actor in a motion picture drama', 1920.0),
#  ('best director of a motion picture', 1900.0),
#  ('best actress in a miniseries or tv movie', 1650.0),
#  ('best actress in a comedy or musical', 1650.0),
#  ('best actress in a tv drama', 1650.0),
#  ('best supporting actor in a tv show, miniseries or tv movie', 1295.0),
#  ('best original song category, the golden globe', 1110.0),
#  ('best supporting actor in tv', 1110.0),
#  ('best actress in a tv comedy', 1100.0),
#  ('best actress in a comedy', 1100.0),
#  ('best actress in a comedy or musical series', 1100.0),
#  ('best actress (drama)', 1100.0),
#  ('best actress for motion picture- drama-', 1100.0),
#  ('best actress in a motion picture for drama', 1100.0),
#  ('best actor for tv drama', 960.0),
#  ('best actor in a motion picture comedy/musical', 960.0),
#  ('best director', 950.0),
#  ('best director for a motion picture', 950.0),
#  ('best supporting actor in a motion picture', 925.0),
#  ('best actor in a comedy', 800.0),
#  ('best original song', 656.25),
#  ('best actress', 550.0),
#  ('best actress in a tv series', 550.0),
#  ('best actress - mini-series', 550.0),
#  ('best actress in a mini-series, tv movie', 550.0),
#  ('best actress comedy or musical', 550.0),
#  ('best actress in a musical or comedy', 550.0),
#  ('best actress in a motion picture (comedy or musical)', 550.0),
#  ('best actress in a motion picture musical/comedy', 550.0),
#  ('best actress tv series drama', 550.0),
#  ('best actress in tv comedy/musical', 550.0),
#  ('best actress in a tv series comedy/musical', 550.0),
#  ('best actress in a television series drama', 550.0),
#  ('best actress - drama', 550.0),
#  ('best actress (motion picture - drama)', 550.0),
#  ('best actress motion picture drama', 550.0),
#  ('best actress for a motion picture drama', 550.0),
#  ('best actress in a drama', 550.0),
#  ('best screenplay in a motion picture', 450.0),
#  ('best screenplay - motion picture', 450.0),
#  ('best actor', 400.0),
#  ('best actor in a tv series or drama', 400.0),
#  ('best actor in a tv drama award', 400.0),
#  ('best actor for tv series drama', 400.0),
#  ('best actor in tv series', 400.0),
#  ('best actor tv series drama', 400.0),
#  ('best actor tv drama award', 400.0),
#  ('best actor in tv drama', 400.0),
#  ('best actor in tv series-drama', 400.0),
#  ('best actor in a tv miniseries', 400.0),
#  ('best actor in a mini-series or motion picture made for television', 400.0),
#  ('best actor in a tv series - comedy or musical', 400.0),
#  ('best actor for tv series comedy or musical', 400.0),
#  ('best actor in a television series in a comedy or musical', 400.0),
#  ('best actor in a tv series', 400.0),
#  ('best actor in a movie, musical or comedy', 400.0),
#  ('best actor in a comedy film', 400.0),
#  ('best actor musical or comedy', 400.0),
#  ('best actor in motion picture', 400.0),
#  ('best actor in a motion picture, comedy/musical', 400.0),
#  ('best actor in a drama', 400.0),
#  ('best actor in a motion picture, drama', 400.0),
#  ('best actor (film/drama)', 400.0),
#  ('best supporting actress', 393.75),
#  ('best supporting actress in a tv movie, series, or miniseries', 370.0),
#  ('best original song motion picture', 370.0),
#  ('best original song in a motion picture', 370.0),
#  ('best supporting actress motion picture', 370.0),
#  ('best supporting actress for motion picture', 370.0),
#  ('best picture', 350.0),
#  ('best picture (musical/comedy)', 350.0),
#  ('best picture - drama', 350.0),
#  ('best picture drama,', 350.0),
#  ('best tv comedy/musical', 315.0),
#  ('best motion picture', 243.75),
#  ('best actress drama', 243.75),
#  ('best screenplay', 225.0),
#  ('best supporting actor', 225.0),
#  ('best screenplay for a motion picture', 225.0),
#  ('rt @rarariot: most sincere/best speech award', 220),
#  ('best supporting actress tv series miniseries or tv movie', 198),
#  ('best supporting actor motion', 196),
#  ('best motion picture, comedy/musical', 195.0),
#  ('best motion picture - drama', 195.0),
#  ('best supporting', 185.0),
#  ('best original', 185.0),
#  ('best supporting actor in a movie', 185.0),
#  ('best supporting actress for tv, miniseries, etc. -', 185.0),
#  ('best supporting actress for tv', 185.0),
#  ('best supporting actress in a television series', 185.0),
#  ('best supporting actress in tv series, mini-series or tv movie', 185.0),
#  ('best supporting actress in a tv show, miniseries or tv movie', 185.0),
#  ('best supporting actress in a tv series', 185.0),
#  ('best original score for a film', 185.0),
#  ('best original song - motion picture', 185.0),
#  ('best supporting actor in a tv show, miniseries or tv movie award', 185.0),
#  ('best supporting actress in a motion picture drama', 185.0),
#  ('best supporting actress in a comedy or musical', 185.0),
#  ('best tv series - drama', 180.0),
#  ('best actress in a motion picture comedy or musical', 135.0),
#  ('best actor, comedy/musical', 130),
#  ('best motion picture in drama', 130.0),
#  ('best song', 125.0),
#  ('best motion picture drama', 125.0),
#  ('best tv series', 112.5),
#  ('best foreign film', 112.5),
#  ('best actress, tv drama', 110),
#  ("best i'm a bi-polar cia agent who just had a baby in real life a month ago &amp; am rocking this red dress",
#   106),
#  ('best speech of the night', 104),
#  ('best performance', 100.0),
#  ('best performance by an actor in a mini series or movie made for tv', 100.0),
#  ('best performance by an actress in a comedy or musical', 100.0),
#  ('best performance by an actress in a tv series, drama', 100.0),
#  ('best performance by an actor in a motion picture, comedy or musical',
#   100.0),
#  ('best performance by an actress in a motion picture, drama', 100.0),
#  ('best performance by an actress in a motion picture - drama', 100.0),
#  ('best director for', 97.5),
#  ('best animated feature', 93.75),
#  ('best supporting actress tv', 88),
#  ('best drama', 87.5),
#  ('best comedy', 87.5),
#  ('best movie', 87.5),
#  ('best miniseries or tv movie', 84),
#  ('best actor in', 82.5),
#  ('best performance by an', 80.0),
#  ('rt @bashville: and the award for "best use of monotone in an acceptance speech"',
#   79),
#  ('best dressed', 75.0),
#  ('best dressed of the night easily', 75.0),
#  ('best dressed of the night at the #goldenglobes', 75.0),
#  ('best director at the', 72),
#  ('best original song for ben http t co orlupzfq', 72),
#  ('best supporting actor in a tv show miniseries or', 72),
#  ('best actor in a', 70.0),
#  ('best actress for', 67.5),
#  ('best motion', 65.0),
#  ('best speech', 65.0),
#  ('best motion picture - comedy or musical', 65.0),
#  ('best motion picture- comedy or musical', 65.0),
#  ('best motion picture comedy or musical', 65.0),
#  ('best motion picture, comedy or musical', 65.0),
#  ('best motion picture - comedy/musical', 65.0),
#  ('best motion picture - drama -', 65.0),
#  ('best motion picture (drama)', 65.0),
#  ('best original song for', 64),
#  ('best screenplay, motion picture', 62),
#  ('best picture: comedy or musical', 62),
#  ('the @goldenglobes award for "best screenplay - motion picture"', 62),
#  ('best performance by', 60.0),
#  ('best actor tv series', 60),
#  ('"best performance by an actor in a miniseries or tv film "', 58),
#  ('best director at', 54),
#  ('best performance by an actress in a supporting role', 54),
#  ('#bestactor for #miniseries or #tvseries #goldenglobes', 53),
#  ('rt @albz: and "best sound"', 52),
#  ('the @goldenglobes award for "best tv series - drama"', 52),
#  ('the @goldenglobes award for "best supporting actor"', 51),
#  ('best animated', 50.0),
#  ('best actress in a', 50.0),
#  ('best supporting actress for', 50.0),
#  ('best tv series drama', 50.0),
#  ('best comedy or musical', 50.0),
#  ('#best #originalscore #montionpicture #goldenglobes', 50),
#  ('best animated feature film:)', 50.0),
#  ('best actor tv', 48),
#  ('best tv', 45.0),
#  ('best actress in', 45.0),
#  ('best original song for skyfall http t co iqapm12s', 45),
#  ('best performance by an actor in a motion picture', 45.0),
#  ('best actress in a mini series or tv movie', 45.0),
#  ('best tv mini-series', 45.0),
#  ('best tv series (drama)', 45.0),
#  ('best tv series- drama', 45.0),
#  ('best tv movie or miniseries actor', 45.0),
#  ('best tv series actress in comedy or musical', 45.0),
#  ('best tv series comedy award', 45.0),
#  ('best tv series - comedy', 45.0),
#  ('best tv comedy or musical', 45.0),
#  ('best director for argo', 44),
#  ('#bestdressed #goldenglobes #goldenglobes2013', 44),
#  ('best #goldenglobes acceptance speech so far', 43),
#  ('best actress, television comedy or musical', 42),
#  ('best director for motion', 40),
#  ('“best supporting actor, motion picture', 38),
#  ('best actor for', 37.5),
#  ('best screenplay for', 37.5),
#  ('best foreign', 35.0),
#  ('best movie - comedy/musical', 35.0),
#  ('best actress, motion picture drama', 34),
#  ('best actress, motion picture/drama', 34),
#  ('and the award for cutest besties', 32),
#  ('best actor, motion picture drama', 32),
#  ('best supporting actor in', 30.0),
#  ('best actress tv', 30),
#  ('best animated film', 30.0),
#  ('best actor drama', 30.0),
#  ('most sincere/best speech award', 30),
#  ('best actor, musical or comedy', 29),
#  ('best miniseries or tv', 28),
#  ('best tv comedy musical', 28),
#  ('best mini-actor in a series', 27),
#  ('best #goldenglobes analysis', 27),
#  ('"best motion picture drama', 26),
#  ('best screenplay motion picture', 25.0),
#  ('best foreign language film', 25.0),
#  ('best animated feature film', 25.0),
#  ('best mini-series/tv movie', 25),
#  ('holy s**t!best screenplay', 25),
#  ('best #goldenglobes speech', 25),
#  ('best picture at the', 24),
#  ('best actress in a tv series drama and probably many best dressed', 24),
#  ('best original song category', 24),
#  ('best supporting actor in a tv series or movie', 22.5),
#  ('best tv series actress in a comedy or musical', 22.5),
#  ('best mini-series or tv', 22),
#  ('best director and', 21),
#  ('best miniseries or', 21),
#  ('best movie/miniseries', 21),
#  ('best supporting actor for', 20),
#  ('best actress at the', 20),
#  ('best screenplay for django', 20),
#  ('best supporting actress in', 20.0),
#  ('best actress tv drama', 20),
#  ('best actress tv series', 20),
#  ('best actor comedy musical', 20),
#  ('best gay porn face', 20.0),
#  ('best drama tv actress', 20.0),
#  ('best mini series or tv movie', 20),
#  ('best comedy/musical', 19),
#  ('best comedy/musical motion picture', 19),
#  ('best musical/comedy', 19),
#  ('best actress, drama', 19),
#  ('best comedy/musical #goldenglobes', 19),
#  ('best tv drama', 18.75),
#  ('best original score', 18.75),
#  ('best tv comedy', 18.75),
#  ('best picture at', 18),
#  ('best supporting actor in a motion picture for django', 18),
#  ('best foreign film because it took place in another', 18),
#  ('best actress in a tv series drama and probably', 18),
#  ('best speech award', 18),
#  ('best supporting actress in a tv movie series or', 18),
#  ('best performance by an actress in a motion picture', 18),
#  ('#bestmotionpicture', 18),
#  ('best actor, drama', 17),
#  ('best speech of the', 16),
#  ('best actress for comedy', 16),
#  ('best actress motion picture', 16),
#  ('best drama. just', 16),
#  ('best actress at', 15),
#  ('best picture musical', 15.0),
#  ('best comedy or', 15.0),
#  ('best comedy musical', 15.0),
#  ('best editing', 15.0),
#  ('best actor comedy', 15),
#  ('best actress comedy', 15.0),
#  ('best supporting hug', 15.0),
#  ('best miniseries', 14),
#  ('best miniseries or tv movie award', 14),
#  ('best actress goldenglobes', 12),
#  ('best supporting actress goldenglobes', 12),
#  ('best supporting goldenglobes me', 12),
#  ('best supporting actor in a motion picture for django unchained goldenglobes yes',
#   12),
#  ('best supporting actor for his work in quentin tarantino s django unchained',
#   12),
#  ('best original song but i would have enjoyed seeing taylor s shocked', 12),
#  ('best supporting actor at the golden globes he was fantastic in it', 12),
#  ('best actress at the goldenglobes she is amazing and i m sure', 12),
#  ('best supporting actress for les miserables on golden globes rt despiqablequis catwoman',
#   12),
#  ('best original screenplay for django unchained it was up against some heavy',
#   12),
#  ('best supporting actress tonight would you name her best dressed as well',
#   12),
#  ('best foreign film but i didn t understand a word of what', 12),
#  ('best screenplay for django apparently there s a solid plot beneath the',
#   12),
#  ('best supporting actor in a motion picture django unchained goldenglobes http t',
#   12),
#  ('best actress drama i got totally distracted by lea michele s spray', 12),
#  ('best animated feature i think brenda chapman should ve been there accepting',
#   12),
#  ('best director and he s not even nominated for an oscar goldenglobes', 12),
#  ('best director in the goldenglobes but wasn t nominated for the oscars', 12),
#  ('best director at the critics choice awards and at the golden globes', 12),
#  ('best performance by an actor in a motion picture musical or comedy', 12),
#  ('best actor in a musical or comedy for his role in les', 12),
#  ('best actor in a comedy or musical in this case a musical', 12),
#  ('best film musical comedy we really want to see that anne and', 12),
#  ('best pic but it s a near certainty it won t at', 12),
#  ('best actress in both categories now its oscar race between two goldenglobes',
#   12),
#  ('best performance by an actor in a motion picture drama for lincoln', 12),
#  ('best actor in a motion picture comedy or musical hugh jackman in', 12),
#  ('best picture and director while matt damon is busy buying zoo s', 12),
#  ('best picture at the oscars without a best director nom since driving', 12),
#  ('best director at the people s choice amp golden globe awards but', 12),
#  ('best actress tonight at the goldenglobes i have been a fan of', 12),
#  ('best picture at the goldenglobes and it wasn t even nominated for', 12),
#  ('best picture but i think zero dark thirty was a better film', 12),
#  ('best motion picture amp hugh jackman amp anne hathaway both won golden',
#   12),
#  ('best motion picture and ben affleck also won best director motion picture',
#   12),
#  ('best movie ever which isn t shocking considering one of the other', 12),
#  ('best picture at the golden globes and i ve never even heard', 12),
#  ('best director and argo won best motion picture drama at the golden', 12),
#  ('best director for argo critics choice movie awards and the golden globes',
#   12),
#  ('best mini series', 12),
#  ('best speech of', 12),
#  ('best actress motion', 12),
#  ('best mini series or', 12),
#  ('best performance by an actor in a mini series or movie made', 12),
#  ('best actor in a mini series or motion picture made for television', 12),
#  ('best supporting actor in a tv show miniseries or tv movie award', 12),
#  ('best i m a bi polar cia agent who just had a', 12),
#  ('best performance by an actor in a motion picture comedy or musical', 12),
#  ('best pic', 10.0),
#  ('best actor for tv', 10.0),
#  ('best original score for', 10.0),
#  ('best original song in', 10.0),
#  ('best actor in tv', 10.0),
#  ('best actress for a', 10.0),
#  ('best original song motion', 10.0),
#  ('best tv series comedy', 10.0),
#  ('best picture musical comedy', 10.0),
#  ('best motion picture comedy', 10.0),
#  ('best director motion picture', 10.0),
#  ('best mini', 10),
#  ('best hair', 10.0),
#  ('best supporting actor award', 10.0),
#  ('best tv drama actor', 10.0),
#  ('best supporting role tonight', 10.0),
#  ('best television series actor', 10.0),
#  ('best drama tv series', 10.0),
#  ('best tv drama series', 10.0),
#  ('best original score award', 10.0),
#  ('best painted on dress', 10.0),
#  ('best original song award', 10.0),
#  ('best presenters so far', 10.0),
#  ('best motion picture screenplay', 10.0),
#  ('best tv drama actress', 10.0),
#  ('best animated film globe', 10.0),
#  ('best tv comedy actress', 10.0),
#  ('best penguin walking impression', 10.0),
#  ('best drama film is', 10.0),
#  ('best pic for comedy musical', 10.0),
#  ('best song goldenglobes', 9),
#  ('best drama at', 9),
#  ('best supporting goldenglobes', 9),
#  ('best actor goldenglobes', 9),
#  ('best supporting actor for his work in quentin tarantino', 9),
#  ('best actress in a musical for some like it', 9),
#  ('best original song for ben http t co csx9c16s', 9),
#  ('best drama before claire danes has won best actress', 9),
#  ('best original song http t co kdzpcx1c getglue goldenglobes', 9),
#  ('best original song in a motion picture for skyfall', 9),
#  ('best original song but i would have enjoyed seeing', 9),
#  ('best song in a motion picture skyfall james bond', 9),
#  ('best drama at the goldenglobes amp damien lewis won', 9),
#  ('best supporting actor at the golden globes he was', 9),
#  ('best motion picture drama goldenglobes that s a given', 9),
#  ('best actress at the goldenglobes she is amazing and', 9),
#  ('best supporting actress for les miserables on golden globes', 9),
#  ('best supporting performance in a series mini series tv', 9),
#  ('best original screenplay for django unchained it was up', 9),
#  ('best supporting actress tonight would you name her best', 9),
#  ('best foreign film but i didn t understand a', 9),
#  ('best screenplay for django apparently there s a solid', 9),
#  ('best supporting actor in a motion picture django unchained', 9),
#  ('best actress drama i got totally distracted by lea', 9),
#  ('best animated movie a year it made a movie', 9),
#  ('best animated feature i think brenda chapman should ve', 9),
#  ('best director and he s not even nominated for', 9),
#  ('best director goldenglobes race is very much open for', 9),
#  ('best director and you didn t even bother to', 9),
#  ('best director in the goldenglobes but wasn t nominated', 9),
#  ('best director especially since he was shut out of', 9),
#  ('best director at the critics choice awards and at', 9),
#  ('best actor in a musical or comedy for his', 9),
#  ('best actor in comedy or musical for the golden', 9),
#  ('best actor in a comedy or musical in this', 9),
#  ('best film musical comedy we really want to see', 9),
#  ('best director met his wife on the set of', 9),
#  ('best pic but it s a near certainty it', 9),
#  ('best actress at the golden globes let me die', 9),
#  ('best actress in both categories now its oscar race', 9),
#  ('best motion picture comedy or musical at the golden', 9),
#  ('best actor in a motion picture comedy or musical', 9),
#  ('best picture one of my favorite movies last year', 9),
#  ('best picture and director while matt damon is busy', 9),
#  ('best picture at the oscars without a best director', 9),
#  ('best director at the people s choice amp golden', 9),
#  ('best movie definitely a game changer for the oscars', 9),
#  ('best director for argo and that it won best', 9),
#  ('best actress tonight at the goldenglobes i have been', 9),
#  ('best pic since the movie has a statenisland connection', 9),
#  ('best supporting actress in a motion picture for les', 9),
#  ('best picture at the goldenglobes and it wasn t', 9),
#  ('best picture on golden globes tonight http t co', 9),
#  ('best director and won best motion picture tonight good', 9),
#  ('best picture but i think zero dark thirty was', 9),
#  ('best motion picture amp hugh jackman amp anne hathaway', 9),
#  ('best tv series drama on the goldenglobes homeland yaymyfav', 9),
#  ('best motion picture and ben affleck also won best', 9),
#  ('best movie ever which isn t shocking considering one', 9),
#  ('best picture at the golden globes and i ve', 9),
#  ('best director and argo won best motion picture drama', 9),
#  ('best director for argo critics choice movie awards and', 9),
#  ('best television series', 9),
#  ('best drama tv', 9),
#  ('best supporting actress in tv series mini series or', 9),
#  ('best supporting actress in a tv show miniseries or', 9),
#  ('best lesbian in a back stage candid video cameo', 9),
#  ('best performance by an actor in a mini series', 9),
#  ('best performance by an actor in a miniseries or', 9),
#  ('best actor in a mini series or motion picture', 9),
#  ('best performance by an actress in a comedy or', 9),
#  ('best actor in a tv series comedy or musical', 9),
#  ('best actor in a television series in a comedy', 9),
#  ('best performance by an actress in a tv series', 9),
#  ('best i m a bi polar cia agent who', 9),
#  ('best supporting actor at', 8),
#  ('best song goldenglobes adelesucks', 8),
#  ('best original song goldenglobe', 8),
#  ('best song in a', 8),
#  ('best drama at the', 8),
#  ('best actress for silver', 8),
#  ('best foreign film because', 8),
#  ('best actress for keeping', 8),
#  ('best dressed lists goldenglobes', 8),
#  ('best animated feature at', 8),
#  ('best actor in the', 8),
#  ('best movie at the', 8),
#  ('best director and argo', 8),
#  ('best television', 8),
#  ('best supporting actress motion', 8),
#  ('best screenplay in a', 8),
#  ('best dressed of the', 8),
#  ('best tan by an', 8),
#  ('best tv series actress', 8),
#  ('best director of a', 8),
#  ('best actor musical or', 8),
#  ('best picture comedy or', 8),
#  ('best actress for motion', 8),
#  ('best motion picture in', 8),
#  ('best tan by an actress', 8),
#  ('best television series, comedy or musical', 8),
#  ('best television series for comedy or musical', 8),
#  ('best screenplay motion', 7.5),
#  ('best foreign language', 7.5),
#  ('best picture drama', 7.5),
#  ('best director motion', 7.5),
#  ('best drama series', 7.5),
#  ('best political shart', 7.5),
#  ('best television drama', 7.5),
#  ('best awkward moment', 7.5),
#  ('best musical score', 7.5),
#  ('best swallowed rooster', 7.5),
#  ('best acceptance speech', 7.5),
#  ('best affair ever', 7.5),
#  ('best comedic combo', 7.5),
#  ('best presenters ever', 7.5),
#  ('best supporting handjob', 7.5),
#  ('best disapperaing act', 7.5),
#  ('best comedy series', 7.5),
#  ('best movie award', 7.5),
#  ('best film drama', 7.5),
#  ('best speech yet', 7.5),
#  ('best song in', 6),
#  ('best screenplay goldenglobes', 6),
#  ('best screenplay django', 6),
#  ('best dressed lists', 6),
#  ('best animated picture', 6),
#  ('best director goldenglobes', 6),
#  ('best movie at', 6),
#  ('best goldenglobes', 6),
#  ('best use of', 6),
#  ('best gay porn', 6),
#  ('best screenplay in', 6),
#  ('best dressed of', 6),
#  ('best tan by', 6),
#  ('best director of', 6),
#  ('best actor musical', 6),
#  ('best picture comedy', 6),
#  ('best film', 5.0),
#  ('best humans', 5.0),
#  ('best direction', 5.0),
#  ('best jury', 5.0),
#  ('best actress for her', 4),
#  ('best actress on mini', 4),
#  ('best actor for django', 4),
#  ('best actor for a', 4),
#  ('best actor on a', 4),
#  ('best drama before claire', 4),
#  ('best tv drama goldenglobes', 4),
#  ('best song for skyfall', 4),
#  ('best original song congrats', 4),
#  ('best original song lol', 4),
#  ('best original song http', 4),
#  ('best original song but', 4),
#  ('best original song haha', 4),
#  ('best supporting actor goldenglobes', 4),
#  ('best skin tight dress', 4),
#  ('best song at the', 4),
#  ('best director for dances', 4),
#  ('best actress goldenglobes http', 4),
#  ('best actress for les', 4),
#  ('best supporting performance in', 4),
#  ('best screenplay goldenglobes2013 goldenglobes', 4),
#  ('best actor goldenglobes djangounchained', 4),
#  ('best screenplay django goldenglobes', 4),
#  ('best original screenplay for', 4),
#  ('best screenplay goldenglobes say', 4),
#  ('best supporting actress tonight', 4),
#  ('best dressed as well', 4),
#  ('best blurry picture with', 4),
#  ('best foreign film but', 4),
#  ('best actress drama i', 4),
#  ('best animated movie a', 4),
#  ('best animated picture in', 4),
#  ('best animated feature i', 4),
#  ('best life time achievement', 4),
#  ('best director and he', 4),
#  ('best director goldenglobes race', 4),
#  ('best director and you', 4),
#  ('best tv show musical', 4),
#  ('best director in the', 4),
#  ('best director for the', 4),
#  ('best tv comedy series', 4),
#  ('best director especially since', 4),
#  ('best director argo s', 4),
#  ('best tv series totally', 4),
#  ('best anal sex scene', 4),
#  ('best actor lesmis goldenglobes', 4),
#  ('best actor in comedy', 4),
#  ('best motion picture musical', 4),
#  ('best film musical comedy', 4),
#  ('best motion picture for', 4),
#  ('best director met his', 4),
#  ('best pic but it', 4),
#  ('best actress in both', 4),
#  ('best actor for lincoln', 4),
#  ('best actor says no', 4),
#  ('best actor for lincolnmovie', 4),
#  ('best actress for zerodarkthirty', 4),
#  ('best actress for zero', 4),
#  ('best motion picture goldenglobes', 4),
#  ('best animated feature goldenglobes', 4),
#  ('best picture one of', 4),
#  ('best picture for drama', 4),
#  ('best picture and director', 4),
#  ('best director nom since', 4),
#  ('best dressed in my', 4),
#  ('best movie definitely a', 4),
#  ('best comedy musical right', 4),
#  ('best actor so all', 4),
#  ('best dressed hands down', 4),
#  ('best director and youu', 4),
#  ('best director and best', 4),
#  ('best drama at goldenglobes', 4),
#  ('best actress tonight at', 4),
#  ('best pic since the', 4),
#  ('best screenplay and supporting', 4),
#  ('best picture in the', 4),
#  ('best picture on golden', 4),
#  ('best director and won', 4),
#  ('best motion picture tonight', 4),
#  ('best picture but i', 4),
#  ('best motion picture amp', 4),
#  ('best motion picture and', 4),
#  ('best movie ever which', 4),
#  ('best sound', 4),
#  ('best use', 4),
#  ('best musical', 4),
#  ('best gay', 4),
#  ('best presenters', 4),
#  ('best tan', 4),
#  ('best mini series tv', 4),
#  ('best tv mini series', 4),
#  ('best actress mini series', 4),
#  ('best actor tv drama', 4),
#  ('best imitation of snl', 4),
#  ('best use of a', 4),
#  ('best originalscore montionpicture goldenglobes', 4),
#  ('best lesbian in a', 4),
#  ('best goldenglobes acceptance speech', 4),
#  ('best golden globes acceptance', 4),
#  ('best outfit of the', 4),
#  ('best use of monotone', 4),
#  ('best tv movie or', 4),
#  ('best real life quote', 4),
#  ('best accessory of the', 4),
#  ('best punchline by an', 4),
#  ('best actress comedy or', 4),
#  ('best screenplay for a', 4),
#  ('best mini actor in', 4),
#  ('best drunken acceptance speech', 4),
#  ('best i m a', 4),
#  ('best actress in tv', 4),
#  ('best future gif of', 4),
#  ('best actress television comedy', 4),
#  ('best series of non', 4),
#  ('best director for a', 4),
#  ('best television series comedy', 4),
#  ('best theme of the', 4),
#  ('best tv comedy or', 4),
#  ('best actor in motion', 4),
#  ('best movie comedy musical', 4),
#  ('best comedy musical motion', 4),
#  ('best pic for comedy', 4),
#  ('best actor motion picture', 4),
#  ('best livetweeter of the', 4),
#  ('best actor film drama', 4),
#  ('best comedy musical goldenglobes', 4),
#  ('best television series for', 4),
#  ('best use of a large doily', 4),
#  ('best actress on', 3),
#  ('best actor on', 3),
#  ('best drama before', 3),
#  ('best song for', 3),
#  ('best skin tight', 3),
#  ('best song at', 3),
#  ('best drama goldenglobes', 3),
#  ('best supporting performance', 3),
#  ('best screenplay goldenglobes2013', 3),
#  ('best original screenplay', 3),
#  ('best dressed as', 3),
#  ('best blurry picture', 3),
#  ('best animated movie', 3),
#  ('best dressed tonight', 3),
#  ('best life time', 3),
#  ('best tv show', 3),
#  ('best director in', 3),
#  ('best director especially', 3),
#  ('best director argo', 3),
#  ('best anal sex', 3),
#  ('best husband ever', 3),
#  ('best actor lesmis', 3),
#  ('best film musical', 3),
#  ('best director met', 3),
#  ('best pic but', 3),
#  ('best movie goldenglobes', 3),
#  ('best actor says', 3),
#  ('best picture one', 3),
#  ('best picture for', 3),
#  ('best picture and', 3),
#  ('best director nom', 3),
#  ('best dressed in', 3),
#  ('best movie definitely', 3),
#  ('best actor so', 3),
#  ('best dressed hands', 3),
#  ('best actress tonight', 3),
#  ('best pic since', 3),
#  ('best screenplay and', 3),
#  ('best picture in', 3),
#  ('best picture on', 3),
#  ('best picture but', 3),
#  ('best movie ever', 3),
#  ('best movie miniseries', 3),
#  ('best tv mini', 3),
#  ('best actress mini', 3),
#  ('best supporting role', 3),
#  ('best imitation of', 3),
#  ('best originalscore montionpicture', 3),
#  ('best painted on', 3),
#  ('best lesbian in', 3),
#  ('best goldenglobes acceptance', 3),
#  ('best golden globes', 3),
#  ('best outfit of', 3),
#  ('best tv movie', 3),
#  ('best real life', 3),
#  ('best accessory of', 3),
#  ('best punchline by', 3),
#  ('best presenters so', 3),
#  ('best mini actor', 3),
#  ('best drunken acceptance', 3),
#  ('best i m', 3),
#  ('best penguin walking', 3),
#  ('best future gif', 3),
#  ('best actress television', 3),
#  ('best goldenglobes speech', 3),
#  ('best series of', 3),
#  ('best theme of', 3),
#  ('best movie comedy', 3),
#  ('best pic for', 3),
#  ('best musical comedy', 3),
#  ('best actor motion', 3),
#  ('best livetweeter of', 3),
#  ('best actor film', 3),
#  ('best drama film', 3),
#  ('best drama just', 3),
#  ('best goldenglobes analysis', 3),
#  ('best skin', 2),
#  ('best blurry', 2),
#  ('best life', 2),
#  ('best show', 2),
#  ('best anal', 2),
#  ('best husband', 2),
#  ('best flick', 2),
#  ('best imitation', 2),
#  ('best political', 2),
#  ('best awkward', 2),
#  ('best originalscore', 2),
#  ('best painted', 2),
#  ('best swallowed', 2),
#  ('best acceptance', 2),
#  ('best lesbian', 2),
#  ('best golden', 2),
#  ('best outfit', 2),
#  ('best affair', 2),
#  ('best real', 2),
#  ('best accessory', 2),
#  ('best punchline', 2),
#  ('best comedic', 2),
#  ('best drunken', 2),
#  ('best i', 2),
#  ('best disapperaing', 2),
#  ('best penguin', 2),
#  ('best future', 2),
#  ('best series', 2),
#  ('best theme', 2),
#  ('best livetweeter', 2),
#  ("best imitation of snl's homeland sketch", 2),
#  ('best lesbian in a back-stage candid video cameo', 2),
#  ('best golden globes acceptance speech', 2),
#  ('best outfit of the night', 2),
#  ('best real life quote award', 2),
#  ('best accessory of the night', 2),
#  ('best punchline by an actress', 2),
#  ('best drunken acceptance speech of the night', 2),
#  ('best future gif of the night', 2),
#  ('best series of non sequiturs', 2),
#  ('best theme of the night', 2),
#  ('best livetweeter of the golden globes', 2)]

# %%
import json 
import pandas as pd
import re
import nltk
from nltk.util import ngrams
from collections import Counter

df = pd.read_json("gg2013.json/gg2013.json")
df2 = df[df['text'].str.contains(" hosts ") | df['text'].str.contains(" Hosts ")]
tweets = df2['text'].tolist()

#Find Common correlated Bigrams, for name search, 5 grams for "name and name"
words = []
bigrams = []
pentgrams = []
for tweet in tweets:
 #   tweet = tweet.lower()
    clean_string = re.sub('[^A-Za-z0-9]+', ' ', tweet)
    tokens = nltk.word_tokenize(clean_string)
    grams1 = ngrams(tokens, 1)
    grams2 = ngrams(tokens, 2)
    grams5 = ngrams(tokens, 5)
    for gram in grams1:
        words.append(gram)
    for gram in grams2:
        bigrams.append(gram)
    for gram in grams5:
        pentgrams.append(gram)
    common1 = Counter(words).most_common()
    common2 = Counter(bigrams).most_common()
    common5 = Counter(pentgrams).most_common()
names = nltk.corpus.names.words()

def accumulate_votes(words, bigrams, pentgrams):
    hosts = {}
    for word in words:
        untokenize = ' '.join(word[0])
        hosts[untokenize] = word[1] 
    for gram in bigrams:
        untokenize = ' '.join(gram[0])
        votes = gram[1]
        if gram[0][0] in hosts:
            if gram[0][0] in names:
                votes *= 2
            votes += hosts[gram[0][0]]
        if gram[0][1] in hosts:
            if gram[0][1] in names:
                votes *= 2
            votes += hosts[gram[0][1]]
        if gram[0][1][0].isupper() and gram[0][0][0].isupper():
            votes *= 2
        hosts[untokenize] = votes
    for gram in pentgrams:
        if gram[0][0] == "Hosts":
            host1 = gram[0][1] + " " + gram[0][2]
            if host1 in hosts:
                hosts[host1] = hosts[host1] * 2
            host2 = gram[0][3] + " " + gram[0][4]
            if host2 in hosts:
                hosts[host2] = hosts[host2] * 2
        if gram[0][2] == "and":
            host1 = gram[0][0] + " " + gram[0][1]
            if host1 in hosts:
                hosts[host1] = hosts[host1] * 2
            host2 = gram[0][3] + " " + gram[0][4]
            if host2 in hosts:
                hosts[host2] = hosts[host2] * 2
    return sorted(hosts.items(), key = lambda x: x[1], reverse = True)

accumulate_votes(common1, common2, common5)
# Out:
# [('Tina Fey', 5595136),
#  ('Amy Poehler', 650240),
#  ('Will Ferrell', 15264),
#  ('Kristen Wiig', 7552),
#  ('and Amy', 4920),
#  ('Tina Fay', 4536),
#  ('GoldenGlobes Tina', 3272),
#  ('Globes Tina', 2960),
#  ('Tina as', 2776),
#  ('hosts Tina', 2432),
#  ('Amy Pohler', 2272),
#  ('and Tina', 2204),
#  ('Amy GoldenGlobes', 2180),
#  ('to Tina', 1960),
#  ('for Tina', 1864),
#  ('Tina are', 1776),
#  ('Fey Amy', 1748),
#  ('Tina Amy', 1676),
#  ('Amy Poelher', 1652),
#  ('the hosts', 1632),
#  ('Amy are', 1624),
#  ('hosts Amy', 1192),
#  ('Hosts Tina', 1180),
#  ('Golden Globes', 1178),
#  ('Loving Tina', 1168),
#  ('Tina Are', 1144),
#  ('Tina the', 1140),
#  ('Did Amy', 1136),
#  ('Amy Thank', 1132),
#  ('Amy Hilarious', 1132),
#  ('GetAClueTV Amy', 1128),
#  ('Amy Phoehler', 1124),
#  ('Amy Poehlers', 1124),
#  ('Amy Poheler', 1124),
#  ('Amy Son', 1122),
#  ('IzzyInTheHizzie Tina', 1120),
#  ('Bravo Tina', 1120),
#  ('the Golden', 1090),
#  ('hosts Fey', 1080),
#  ('GoldenGlobes She', 1068),
#  ('Will Farrell', 1056),
#  ('Will Tina', 1052),
#  ('RT David', 1046),
#  ('RT Maria', 1046),
#  ('RT Mary', 1046),
#  ('RT Jill', 1046),
#  ('Globes Kristen', 1026),
#  ('Kristen Wig', 1024),
#  ('and Kristen', 1003),
#  ('Wiig GoldenGlobes', 938),
#  ('hilarious hosts', 934),
#  ('Great hosts', 924),
#  ('hosts TinaFey123', 920),
#  ('funniest hosts', 916),
#  ('both hosts', 916),
#  ('Hosts Amy', 904),
#  ('EW Will', 902),
#  ('Fey GoldenGlobes', 886),
#  ('and Will', 883),
#  ('Fey RT', 864),
#  ('RT EW', 832),
#  ('GoldenGlobes hosts', 829),
#  ('for next', 820),
#  ('hosts and', 809),
#  ('that Amy', 808),
#  ('Globes Love', 794),
#  ('Amy need', 790),
#  ('Globes Red', 788),
#  ('Globes VirginRadio96', 788),
#  ('Pre Globes', 788),
#  ('Globes Don', 786),
#  ('Ferrell GoldenGlobes', 776),
#  ('Amy to', 772),
#  ('I are', 764),
#  ('hosts the', 763),
#  ('Tina and', 744),
#  ('Loving Fey', 744),
#  ('hosts GoldenGlobes', 739),
#  ('year Will', 718),
#  ('Fey Taurus', 716),
#  ('Amy best', 712),
#  ('and Kristin', 709),
#  ('Amy and', 708),
#  ('Tina best', 708),
#  ('and Anne', 707),
#  ('and Leslie', 707),
#  ('GoldenGlobes I', 696),
#  ('Globes Hosts', 686),
#  ('Can Tina', 672),
#  ('http t', 666),
#  ('with Amy', 656),
#  ('Amy more', 656),
#  ('Globes hosts', 653),
#  ('Fey and', 650),
#  ('all the', 648),
#  ('hosts next', 647),
#  ('them Tina', 624),
#  ('RT HuffPostWomen', 610),
#  ('Fey Poehler', 598),
#  ('The GoldenGlobes', 596),
#  ('best hosts', 594),
#  ('Amy were', 594),
#  ('GoldenGlobes Best', 592),
#  ('RT TVGuide', 590),
#  ('Best GoldenGlobes', 590),
#  ('make Amy', 588),
#  ('hosts for', 587),
#  ('hosts to', 587),
#  ('Amy would', 586),
#  ('KiraCostello Tina', 584),
#  ('enough Amy', 584),
#  ('the Red', 584),
#  ('hosts this', 582),
#  ('hosts ever', 581),
#  ('Love Tina', 580),
#  ('And Amy', 580),
#  ('the GoldenGlobes', 577),
#  ('Omg Amy', 576),
#  ('Wiig hosts', 576),
#  ('hosts are', 574),
#  ('w Amy', 572),
#  ('Amy Greatest', 568),
#  ('loving Amy', 568),
#  ('Ferrell and', 566),
#  ('hosts of', 564),
#  ('RT TIME', 564),
#  ('Tina So', 564),
#  ('Oof Amy', 564),
#  ('ReneeBargh Amy', 564),
#  ('BreeeSaunders Amy', 564),
#  ('Loved Tina', 564),
#  ('after Tina', 564),
#  ('Amy until', 564),
#  ('Amy Polher', 562),
#  ('buckleyjason Tina', 560),
#  ('Putting Tina', 560),
#  ('Methinks Tina', 560),
#  ('S Tina', 560),
#  ('Tina go', 560),
#  ('Tina fey', 560),
#  ('Globes I', 558),
#  ('Tina Leave', 558),
#  ('hosts http', 558),
#  ('Globes A', 554),
#  ('as hosts', 552),
#  ('Dear GoldenGlobes', 552),
#  ('GoldenGlobes Are', 552),
#  ('hosts goldenglobes', 549),
#  ('for hosts', 549),
#  ('s hosts', 548),
#  ('GoldenGlobes When', 546),
#  ('EVER GoldenGlobes', 546),
#  ('goldenglobes hosts', 546),
#  ('RT ELLEmagazine', 544),
#  ('GoldenGlobes EVER', 544),
#  ('Great GoldenGlobes', 544),
#  ('GoldenGlobes Great', 544),
#  ('Ricky GoldenGlobes', 540),
#  ('My GoldenGlobes', 538),
#  ('Farrell GoldenGlobes', 538),
#  ('RT Deggans', 536),
#  ('RT KiraCostello', 536),
#  ('hosts I', 536),
#  ('GoldenGlobes Agreed', 536),
#  ('of hosts', 534),
#  ('Yes RT', 534),
#  ('Tonys GoldenGlobes', 534),
#  ('GoldenGlobes Hiiiilaaaaaarious', 534),
#  ('DEAD GoldenGlobes', 534),
#  ('Both GoldenGlobes', 534),
#  ('GoldenGlobes FUCK', 534),
#  ('GoldenGlobes GoldenGlobes2013', 534),
#  ('GoldenGlobes BringThemOut', 534),
#  ('GoldenGlobes AwardsFeveronFMP', 534),
#  ('RT The12Signs', 532),
#  ('YES RT', 530),
#  ('PLEASE RT', 528),
#  ('RT AFP', 526),
#  ('Please RT', 526),
#  ('RT SmGirlFriends', 524),
#  ('RT HeyHolcomb', 524),
#  ('RT Nourieeee', 524),
#  ('RT IzzyInTheHizzie', 524),
#  ('RT GetAClueTV', 524),
#  ('RT ReneeBargh', 524),
#  ('RT BreeeSaunders', 524),
#  ('This RT', 524),
#  ('AshleyMcGovern RT', 524),
#  ('RT ASCPR', 524),
#  ('RT ShockUhDeliCA', 524),
#  ('Compro RT', 524),
#  ('RT HerLateNightCra', 524),
#  ('RT EvaFragiskatos', 524),
#  ('RT Megpie', 524),
#  ('RT TheAdvocateMag', 524),
#  ('RT GerardMulligan1', 524),
#  ('RT AllWomeninMedia', 524),
#  ('RT Hello', 524),
#  ('RT MattBorrelli', 524),
#  ('RT TinaCharlesTV', 524),
#  ('RT Paul403', 524),
#  ('show hosts', 521),
#  ('hosts host', 515),
#  ('Kristen Wigg', 512),
#  ('hosts as', 510),
#  ('Will Ferrel', 504),
#  ('Kristin Wiig', 504),
#  ('Best hosts', 501),
#  ('The hosts', 501),
#  ('Wiig and', 500),
#  ('Hollywood hosts', 500),
#  ('that Fey', 500),
#  ('hosts from', 499),
#  ('Poehler and', 496),
#  ('hosts that', 494),
#  ('Kristen Bell', 494),
#  ('Larsen Wiig', 492),
#  ('have hosts', 490),
#  ('be hosts', 489),
#  ('hosts an', 489),
#  ('Poehler are', 488),
#  ('hosts 2014', 488),
#  ('hosts in', 488),
#  ('hosts The', 487),
#  ('the Globes', 486),
#  ('is hosts', 485),
#  ('and Poehler', 484),
#  ('hosts so', 477),
#  ('hosts with', 477),
#  ('hosts at', 476),
#  ('and Wiig', 476),
#  ('and Ferrell', 476),
#  ('Kristen and', 475),
#  ('The Golden', 474),
#  ('Best Golden', 472),
#  ('award hosts', 471),
#  ('great hosts', 470),
#  ('better hosts', 469),
#  ('hosts were', 469),
#  ('hosts not', 469),
#  ('our hosts', 468),
#  ('hosts if', 468),
#  ('hosts on', 468),
#  ('hosts every', 468),
#  ('good hosts', 467),
#  ('funny hosts', 467),
#  ('hosts please', 465),
#  ('hosts amazing', 464),
#  ('hosts better', 464),
#  ('amazing hosts', 464),
#  ('hosts was', 463),
#  ('When hosts', 462),
#  ('hosts de', 462),
#  ('hosts EVER', 462),
#  ('see hosts', 462),
#  ('hosts tonight', 462),
#  ('hosts will', 462),
#  ('Ferrell are', 462),
#  ('watching hosts', 461),
#  ('women hosts', 461),
#  ('hosts or', 461),
#  ('hosts by', 461),
#  ('hosts should', 461),
#  ('are and', 461),
#  ('hosts had', 461),
#  ('your hosts', 460),
#  ('de hosts', 460),
#  ('about hosts', 459),
#  ('hosts since', 459),
#  ('hosts because', 459),
#  ('hosts right', 459),
#  ('favorite hosts', 459),
#  ('hosts always', 459),
#  ('any hosts', 459),
#  ('gt hosts', 459),
#  ('always hosts', 459),
#  ('hosts out', 459),
#  ('AMAZING hosts', 458),
#  ('azizansari hosts', 458),
#  ('Greatest hosts', 458),
#  ('ass hosts', 458),
#  ('hosts back', 458),
#  ('hosts amypoehler', 458),
#  ('hosts than', 458),
#  ('hosts too', 458),
#  ('hosts maybe', 458),
#  ('Next hosts', 458),
#  ('hosts actually', 458),
#  ('Carpet hosts', 457),
#  ('las hosts', 457),
#  ('perfect hosts', 457),
#  ('hosts until', 457),
#  ('she hosts', 457),
#  ('hosts go', 457),
#  ('hosts during', 457),
#  ('having hosts', 457),
#  ('hosts after', 457),
#  ('hosts asked', 456),
#  ('hosts possible', 456),
#  ('mejores hosts', 456),
#  ('hosts que', 456),
#  ('hosts suck', 456),
#  ('ActuallyNPH hosts', 456),
#  ('lady hosts', 456),
#  ('hosts lol', 456),
#  ('Amazing hosts', 456),
#  ('hosts Hands', 456),
#  ('hosts TinaFeyAmyPoehler', 456),
#  ('Mejores hosts', 456),
#  ('hosts del', 456),
#  ('greatest hosts', 456),
#  ('female hosts', 456),
#  ('hosts cause', 456),
#  ('Those hosts', 456),
#  ('permanent hosts', 456),
#  ('GG hosts', 456),
#  ('hosts everrr', 456),
#  ('hosts yet', 456),
#  ('gg hosts', 456),
#  ('Our hosts', 456),
#  ('Nossa hosts', 456),
#  ('hosts again', 456),
#  ('Jr hosts', 456),
#  ('hosts period', 456),
#  ('hosts eveeeerr', 456),
#  ('excellent hosts', 456),
#  ('hosts killed', 456),
#  ('tweet hosts', 456),
#  ('limiting hosts', 456),
#  ('hosts airtime', 456),
#  ('hosts ended', 456),
#  ('hosts though', 456),
#  ('hosts', 454),
#  ('Poehler s', 450),
#  ('are the', 445),
#  ('Wiig for', 442),
#  ('ever Tina', 438),
#  ('and I', 436),
#  ('the best', 422),
#  ('Dear Golden', 422),
#  ('Will Hosts', 422),
#  ('t the', 419),
#  ('MTV Golden', 416),
#  ('News Golden', 414),
#  ('Poehler I', 414),
#  ('Ferrell the', 413),
#  ('Nightmare Quentin', 410),
#  ('LiveWire Golden', 410),
#  ('CZFM Golden', 410),
#  ('Chat Golden', 408),
#  ('year the', 408),
#  ('Globes Are', 408),
#  ('Globes Why', 406),
#  ('Wiig I', 406),
#  ('Music Golden', 406),
#  ('Social Golden', 406),
#  ('Golden Globe', 406),
#  ('to the', 405),
#  ('Globes Great', 404),
#  ('for the', 402),
#  ('Globes And', 402),
#  ('and more', 401),
#  ('of the', 399),
#  ('the next', 397),
#  ('Globes Well', 396),
#  ('and need', 396),
#  ('and forever', 395),
#  ('Globes HollywoodLife', 394),
#  ('Globes Soooooo', 394),
#  ('Globes Our', 394),
#  ('the http', 394),
#  ('the goldenglobes', 387),
#  ('TVGuide Kristen', 386),
#  ('year GoldenGlobes', 385),
#  ('need to', 384),
#  ('like Fey', 384),
#  ('and all', 384),
#  ('amp Amy', 382),
#  ('t Kristen', 379),
#  ('the Hosts', 378),
#  ('Hosts the', 377),
#  ('GoldenGlobes are', 374),
#  ('are GoldenGlobes', 374),
#  ('from the', 373),
#  ('Amy for', 372),
#  ('for goldenglobes', 370),
#  ('and they', 370),
#  ('and you', 369),
#  ('Is A', 368),
#  ('A Sexual', 368),
#  ('award and', 368),
#  ('husband and', 367),
#  ('Smith and', 367),
#  ('for GoldenGlobes', 366),
#  ('and wife', 366),
#  ('and every', 366),
#  ('globes and', 365),
#  ('amp Tina', 364),
#  ('ever GoldenGlobes', 363),
#  ('Tarantino and', 363),
#  ('and Homeland', 362),
#  ('Can Kristen', 362),
#  ('and will', 360),
#  ('and amy', 359),
#  ('Taurus and', 358),
#  ('TinaFey123 and', 358),
#  ('Wig and', 357),
#  ('any and', 357),
#  ('Fay and', 357),
#  ('GoldenGlobes this', 357),
#  ('always and', 357),
#  ('AmyPoehler and', 357),
#  ('and TinaFey', 357),
#  ('the show', 356),
#  ('that Tina', 356),
#  ('Tiny and', 356),
#  ('fey and', 356),
#  ('and both', 356),
#  ('tinafey and', 356),
#  ('and amypoehler', 356),
#  ('Wigg and', 356),
#  ('RT goldenglobes', 355),
#  ('s GoldenGlobes', 355),
#  ('and funniest', 355),
#  ('Rudd and', 355),
#  ('and fun', 355),
#  ('Pohler and', 355),
#  ('talking and', 354),
#  ('gorgeous and', 354),
#  ('Fey And', 354),
#  ('She and', 354),
#  ('Her and', 354),
#  ('gabrielledoug and', 354),
#  ('and Aly', 354),
#  ('and Salma', 354),
#  ('humor and', 354),
#  ('Ferrel and', 354),
#  ('Hosts Ricky', 354),
#  ('and neither', 354),
#  ('commentary and', 354),
#  ('Palin and', 354),
#  ('wax and', 354),
#  ('and congrats', 354),
#  ('davecribb and', 354),
#  ('wiig and', 354),
#  ('ermahgerdmergan and', 354),
#  ('host the', 353),
#  ('and', 352),
#  ('this RT', 352),
#  ('as the', 349),
#  ('of GoldenGlobes', 345),
#  ('be Tina', 344),
#  ('best GoldenGlobes', 343),
#  ('Opening Monologue', 342),
#  ('Monologue Is', 342),
#  ('Sexual Nightmare', 342),
#  ('Hosts I', 336),
#  ('RT fuggirls', 334),
#  ('is the', 334),
#  ('t co', 332),
#  ('ever Fey', 332),
#  ('that the', 330),
#  ('this Golden', 329),
#  ('Amy amp', 328),
#  ('show GoldenGlobes', 328),
#  ('in the', 327),
#  ('be the', 327),
#  ('next year', 323),
#  ('have the', 323),
#  ('Tina amp', 318),
#  ('at the', 316),
#  ('Poehler The', 316),
#  ('the golden', 314),
#  ('attending the', 314),
#  ('Poehler Best', 314),
#  ('with the', 314),
#  ('2014 GoldenGlobes', 310),
#  ('Golden http', 310),
#  ('the object', 308),
#  ('were the', 307),
#  ('goldenglobes Will', 307),
#  ('the award', 306),
#  ('2013 Tina', 304),
#  ('Globes are', 304),
#  ('think Tina', 304),
#  ('on the', 303),
#  ('the 70th', 302),
#  ('love Amy', 302),
#  ('if the', 302),
#  ('Globes http', 301),
#  ('far the', 301),
#  ('Loving the', 300),
#  ('the red', 300),
#  ('already the', 299),
#  ('the time', 299),
#  ('Fey are', 298),
#  ('see the', 298),
#  ('make the', 298),
#  ('the history', 297),
#  ('by the', 297),
#  ('Love the', 297),
#  ('for Golden', 296),
#  ('the point', 296),
#  ('If the', 296),
#  ('love Tina', 296),
#  ('could the', 296),
#  ('And the', 296),
#  ('know the', 296),
#  ('the women', 296),
#  ('how the', 295),
#  ('found the', 295),
#  ('the same', 294),
#  ('the source', 294),
#  ('the choices', 294),
#  ('since the', 294),
#  ('the opening', 294),
#  ('than the', 294),
#  ('the made', 294),
#  ('where the', 294),
#  ('the presenters', 294),
#  ('been the', 294),
#  ('both the', 294),
#  ('least the', 294),
#  ('the event', 294),
#  ('the person', 293),
#  ('the perfect', 293),
#  ('Bring the', 293),
#  ('during the', 293),
#  ('the park', 293),
#  ('working the', 293),
#  ('Did the', 293),
#  ('the funniest', 293),
#  ('who the', 293),
#  ('Loved the', 293),
#  ('the anchors', 292),
#  ('the Today', 292),
#  ('From the', 292),
#  ('hear the', 292),
#  ('the TV', 292),
#  ('Seeing the', 292),
#  ('like Tina', 292),
#  ('liked the', 292),
#  ('the corny', 292),
#  ('bless the', 292),
#  ('the first', 292),
#  ('probably the', 292),
#  ('Probably the', 292),
#  ('Watching the', 292),
#  ('still the', 292),
#  ('the greatest', 292),
#  ('the Oscars', 292),
#  ('enjoying the', 292),
#  ('the audience', 292),
#  ('the bes', 292),
#  ('the crowd', 292),
#  ('reached the', 292),
#  ('thinks the', 292),
#  ('Imagine the', 292),
#  ('the possibilities', 292),
#  ('beat the', 292),
#  ('wins the', 292),
#  ('the HILARIOUS', 292),
#  ('the announcer', 292),
#  ('run the', 292),
#  ('the decisions', 292),
#  ('the winners', 292),
#  ('the oscars', 292),
#  ('let the', 292),
#  ('the SAGS', 292),
#  ('ended the', 292),
#  ('Tina were', 291),
#  ('the', 290),
#  ('s Golden', 290),
#  ('because Amy', 288),
#  ('Ever A', 288),
#  ('agree RT', 288),
#  ('Vote Will', 286),
#  ('y Amy', 286),
#  ('it GoldenGlobes', 286),
#  ('than Amy', 286),
#  ('thebobbieoliver Tina', 284),
#  ('them GoldenGlobes', 284),
#  ('done Amy', 284),
#  ('than Tina', 284),
#  ('w Tina', 284),
#  ('Amy when', 284),
#  ('tmusings Amy', 282),
#  ('certifies Amy', 282),
#  ('say Tina', 282),
#  ('GoldenGlobes you', 282),
#  ('loving Tina', 282),
#  ('ever Golden', 282),
#  ('que Tina', 280),
#  ('Tina y', 280),
#  ('decided Tina', 280),
#  ('vote Tina', 280),
#  ('lorialvey Tina', 280),
#  ('lizzy Tina', 280),
#  ('terrymeiners Tina', 280),
#  ('ejeancarroll Tina', 280),
#  ('usweekly GoldenGlobes', 279),
#  ('Amy', 278),
#  ('on GoldenGlobes', 278),
#  ('great GoldenGlobes', 278),
#  ('far GoldenGlobes', 277),
#  ('GoldenGlobes would', 277),
#  ('Tina', 276),
#  ('Poehler please', 276),
#  ('please GoldenGlobes', 276),
#  ('GoldenGlobes hilarious', 276),
#  ('time GoldenGlobes', 275),
#  ('RT usweekly', 274),
#  ('GoldenGlobes time', 274),
#  ('Poehler Are', 272),
#  ('GoldenGlobes ceremony', 271),
#  ('out GoldenGlobes', 271),
#  ('years GoldenGlobes', 271),
#  ('there GoldenGlobes', 271),
#  ('now GoldenGlobes', 270),
#  ('GoldenGlobes while', 270),
#  ('favorite GoldenGlobes', 270),
#  ('amazing RT', 270),
#  ('enough GoldenGlobes', 270),
#  ('RT naturallysteph', 269),
#  ('GoldenGlobes glush', 269),
#  ('can RT', 269),
#  ('los GoldenGlobes', 269),
#  ('RT m', 269),
#  ('back GoldenGlobes', 269),
#  ('shows GoldenGlobes', 269),
#  ('funnier GoldenGlobes', 269),
#  ('too GoldenGlobes', 269),
#  ('maybe GoldenGlobes', 269),
#  ('made GoldenGlobes', 269),
#  ('GoldenGlobes what', 269),
#  ('night GoldenGlobes', 268),
#  ('yes GoldenGlobes', 268),
#  ('GoldenGlobes did', 268),
#  ('seen GoldenGlobes', 268),
#  ('forever goldenglobes', 268),
#  ('GoldenGlobes predictions', 267),
#  ('garbage GoldenGlobes', 267),
#  ('bd8sABj9 GoldenGlobes', 267),
#  ('recall GoldenGlobes', 267),
#  ('dos GoldenGlobes', 267),
#  ('GoldenGlobes smrtgrls', 267),
#  ('hilar GoldenGlobes', 267),
#  ('everrr GoldenGlobes', 267),
#  ('sayin GoldenGlobes', 267),
#  ('haha GoldenGlobes', 267),
#  ('die GoldenGlobes', 267),
#  ('agrees GoldenGlobes', 267),
#  ('phenomenal GoldenGlobes', 267),
#  ('GoldenGlobes tomorrow', 267),
#  ('peso GoldenGlobes', 267),
#  ('comics GoldenGlobes', 267),
#  ('presence GoldenGlobes', 267),
#  ('remorse GoldenGlobes', 267),
#  ('GoldenGlobes has', 267),
#  ('possibilities GoldenGlobes', 267),
#  ('thereof GoldenGlobes', 267),
#  ('GoldenGlobes 3', 267),
#  ('period GoldenGlobes', 267),
#  ('eveeeerr GoldenGlobes', 267),
#  ('GoldenGlobes kinda', 267),
#  ('RT tonystarkradio', 266),
#  ('RT jonathanwald', 266),
#  ('GoldenGlobes', 265),
#  ('RT grubreport', 265),
#  ('now RT', 265),
#  ('Nightmare James', 264),
#  ('RT thebobbieoliver', 264),
#  ('no RT', 263),
#  ('RT kevinrfree', 263),
#  ('RT teamfollowback', 263),
#  ('they are', 262),
#  ('Poehler Virgo', 262),
#  ('Poehler FunnyGals', 262),
#  ('RT afp', 262),
#  ('RT rubyjnkie', 262),
#  ('rubyjnkie RT', 262),
#  ('RT buckleyjason', 262),
#  ('RT hiphopdancer96', 262),
#  ('1000000 RT', 262),
#  ('RT adryenn', 262),
#  ('RT jwipe', 262),
#  ('RT tmusings', 262),
#  ('RT romain', 262),
#  ('RT lisasj', 262),
#  ('RT jdbardales', 262),
#  ('RT lorialvey', 262),
#  ('RT logan', 262),
#  ('RT azcentral', 262),
#  ('RT kaitlin', 262),
#  ('RT eastwoodmcfly', 262),
#  ('RT thehodgenator', 262),
#  ('RT grokey', 262),
#  ('RT shefinds', 262),
#  ('RT nbc30rock', 262),
#  ('RT craigversion2', 262),
#  ('missing RT', 262),
#  ('RT glennsumi', 262),
#  ('j9jaHZlA RT', 262),
#  ('RT jaysquad', 262),
#  ('RT whatsmynom', 262),
#  ('RT ronaldtheshort', 262),
#  ('RT mena13suvari', 262),
#  ('RT terrymeiners', 262),
#  ('RT kristin', 262),
#  ('RT sheetalsheth', 262),
#  ('RT akmcquade', 262),
#  ('RT katy', 262),
#  ('RT ejeancarroll', 262),
#  ('RT', 260),
#  ('more from', 260),
#  ('Fey s', 260),
#  ('jonathanwald Ferrell', 256),
#  ('Poehler DEAD', 254),
#  ('Poehler Be', 254),
#  ('HerLateNightCra Will', 254),
#  ('Ok Kristen', 254),
#  ('Okay Kristen', 250),
#  ('a Golden', 249),
#  ('Fey best', 248),
#  ('Quentin Tarantino', 244),
#  ('year PLEASE', 242),
#  ('Globes in', 238),
#  ('Hosts The', 238),
#  ('Fey amp', 232),
#  ('Globes have', 228),
#  ('Globes just', 227),
#  ('Globes 2014', 223),
#  ('Poehler goldenglobes', 222),
#  ('are talking', 220),
#  ('Poehler for', 218),
#  ('2014 I', 218),
#  ('Globes drinking', 217),
#  ('TIME Hosts', 216),
#  ('Time http', 216),
#  ('congrats to', 216),
#  ('Ferrell for', 215),
#  ('to Sarah', 215),
#  ('are next', 214),
#  ('Golden globes', 214),
#  ('year s', 213),
#  ('70th Golden', 213),
#  ('year for', 213),
#  ('Globes they', 213),
#  ('to ever', 211),
#  ('Globes 2013', 211),
#  ('this year', 210),
#  ('these Golden', 209),
#  ('to host', 208),
#  ('co Isxt7H7s', 208),
#  ('http http', 207),
#  ('years Golden', 207),
#  ('Globes hilarious', 206),
#  ('music Golden', 206),
#  ('los Golden', 205),
#  ('bes Golden', 203),
#  ('whatsmynom Golden', 203),
#  ('personal Golden', 203),
#  ('Globes will', 203),
#  ('Poehler best', 202),
#  ('Globes was', 202),
#  ('Globes already', 202),
#  ('Fey is', 202),
#  ('Golden', 201),
#  ('s Opening', 201),
#  ('are this', 200),
#  ('amp Will', 199),
#  ('year I', 199),
#  ('Globes its', 197),
#  ('Globes laughing', 197),
#  ('Globes couldn', 197),
#  ('Globes needs', 197),
#  ('Globes wins', 197),
#  ('Globes presentation', 197),
#  ('Ferrell as', 196),
#  ('Maggie Smith', 196),
#  ('for any', 196),
#  ('Globes', 195),
#  ('goldenglobes http', 195),
#  ('amp Kristen', 195),
#  ('Poehler show', 193),
#  ('Hosts to', 193),
#  ('goldenglobes AmyPoehler', 192),
#  ('I m', 190),
#  ('Fey so', 190),
#  ('Hosts http', 190),
#  ('for Ricky', 189),
#  ('be Kristen', 189),
#  ('Fey you', 188),
#  ('Poehler as', 184),
#  ('PHOTO Hosts', 184),
#  ('Hosts Of', 184),
#  ('Hosts for', 181),
#  ('ever goldenglobes', 180),
#  ('Hilarious Hosts', 180),
#  ('Nightmare http', 179),
#  ('Fey make', 179),
#  ('Poelher s', 178),
#  ('See Hosts', 178),
#  ('Hosts Ever', 176),
#  ('Magazine Hosts', 176),
#  ('Hosts Pre', 176),
#  ('EvaFragiskatos Hosts', 176),
#  ('SNL Hosts', 176),
#  ('Yes EW', 176),
#  ('Underused Hosts', 176),
#  ('Fey y', 174),
#  ('this EW', 174),
#  ('ever for', 173),
#  ('Fey knocked', 173),
#  ('Poehler need', 172),
#  ('I your', 172),
#  ('Poehler have', 171),
#  ('Fey', 170),
#  ('of this', 169),
#  ('for best', 169),
#  ('goldenglobes best', 168),
#  ('Um I', 168),
#  ('show http', 166),
#  ('HeyHolcomb I', 166),
#  ('GENIUS I', 166),
#  ('B I', 166),
#  ('I G', 166),
#  ('Have I', 166),
#  ('TinaCharlesTV I', 166),
#  ('said this', 165),
#  ('this before', 165),
#  ('ever Kristin', 165),
#  ('year forever', 163),
#  ('ever I', 163),
#  ('t have', 162),
#  ('Poehler amp', 162),
#  ('t be', 162),
#  ('I ve', 161),
#  ('Ferrell amp', 160),
#  ('Can t', 159),
#  ('amp Wiig', 158),
#  ('Wiig amp', 158),
#  ('Poehler just', 157),
#  ('Poehler is', 156),
#  ('Ferrell be', 156),
#  ('fuggirls I', 155),
#  ('a year', 155),
#  ('HuffPostWomen Can', 154),
#  ('show s', 154),
#  ('show goldenglobes', 154),
#  ('this show', 154),
#  ('of best', 154),
#  ('but we', 153),
#  ('Quentin Tarantin', 152),
#  ('year The', 151),
#  ('think Will', 151),
#  ('host of', 149),
#  ('we needed', 148),
#  ('don t', 148),
#  ('to be', 146),
#  ('t you', 145),
#  ('A Look', 144),
#  ('stage goldenglobes', 143),
#  ('A host', 142),
#  ('t think', 142),
#  ('ever host', 141),
#  ('Will you', 141),
#  ('have to', 140),
#  ('Poehler were', 140),
#  ('t funny', 139),
#  ('to have', 139),
#  ('be next', 139),
#  ('host everything', 138),
#  ('Poehler fake', 138),
#  ('an http', 138),
#  ('to all', 138),
#  ('for 2014', 137),
#  ('every year', 137),
#  ('can t', 137),
#  ('best host', 137),
#  ('t take', 136),
#  ('t use', 136),
#  ('is http', 136),
#  ('t get', 136),
#  ('much t', 136),
#  ('Quentin http', 136),
#  ('Ferrell would', 134),
#  ('Quentin Tara', 134),
#  ('t know', 134),
#  ('Tarantin http', 133),
#  ('Poehler already', 133),
#  ('Poehler should', 133),
#  ('t even', 133),
#  ('Poehler will', 133),
#  ('stars are', 132),
#  ('are attending', 132),
#  ('The Best', 132),
#  ('great year', 132),
#  ('t wait', 132),
#  ('didn t', 132),
#  ('aren t', 132),
#  ('as best', 132),
#  ('everything goldenglobes', 132),
#  ('Ferrell please', 132),
#  ('won t', 132),
#  ('Poehler arrive', 131),
#  ('Don t', 131),
#  ('up http', 130),
#  ('Couldn t', 130),
#  ('couldn t', 130),
#  ('t breathe', 130),
#  ('isn t', 130),
#  ('t he', 130),
#  ('t hold', 130),
#  ('Aren t', 130),
#  ('for a', 130),
#  ('we all', 129),
#  ('s a', 129),
#  ('t', 128),
#  ('Can we', 128),
#  ('ever grace', 128),
#  ('Poehler didn', 128),
#  ('Poehler aren', 128),
#  ('are killing', 127),
#  ('more of', 127),
#  ('Poehler kill', 127),
#  ('Poehler together', 127),
#  ('Poehler hilar', 127),
#  ('Poehler receive', 127),
#  ('Ferrell gt', 127),
#  ('Poehler excellent', 127),
#  ('for an', 127),
#  ('this be', 126),
#  ('show gabrielledoug', 126),
#  ('Poehler', 125),
#  ('shefinds Kristen', 125),
#  ('are great', 124),
#  ('stage for', 124),
#  ('this is', 124),
#  ('goldenglobes The', 124),
#  ('The goldenglobes', 124),
#  ('eastwoodmcfly Ferrell', 124),
#  ('Ferrell endofstory', 124),
#  ('Will', 123),
#  ('I never', 123),
#  ('And year', 123),
#  ('year If', 123),
#  ('are not', 123),
#  ('Ferrell', 122),
#  ('needed more', 122),
#  ('awards show', 122),
#  ('not to', 122),
#  ('Next year', 122),
#  ('year YES', 122),
#  ('year Just', 122),
#  ('Kristen', 121),
#  ('Wiig', 121),
#  ('are amazing', 121),
#  ('year azizansari', 121),
#  ('never ever', 121),
#  ('year where', 121),
#  ('year Let', 121),
#  ('ve never', 120),
#  ('co 33nnrrsQ', 120),
#  ('that I', 120),
#  ('year after', 120),
#  ('year That', 120),
#  ('everything forever', 119),
#  ('forever J', 119),
#  ('of everything', 119),
#  ('goldenglobes 2014', 119),
#  ('are hilarious', 119),
#  ('we ve', 118),
#  ('amypoehler as', 118),
#  ('Nightmare Quenti', 118),
#  ('Poehlers Opening', 118),
#  ('Nightmare Ja', 118),
#  ('s Best', 118),
#  ('year', 117),
#  ('Smi http', 117),
#  ('before but', 116),
#  ('It s', 116),
#  ('carpet http', 116),
#  ('to see', 116),
#  ('carpet to', 116),
#  ('are already', 116),
#  ('are by', 116),
#  ('to love', 116),
#  ('They are', 116),
#  ('far http', 115),
#  ('Fay are', 115),
#  ('to do', 115),
#  ('never said', 114),
#  ('get to', 114),
#  ('to make', 114),
#  ('like to', 114),
#  ('show stage', 113),
#  ('redcarpet http', 113),
#  ('are doing', 113),
#  ('have ever', 113),
#  ...]
